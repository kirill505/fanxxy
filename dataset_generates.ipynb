# %%
import os
import requests
import pandas as pd

# %%
storeez = pd.read_csv('./osnovnoi_products_20200406_133129.csv', sep=';')

# %%
storeez
# Out:
#        available            categoryId currencyId      id  \
# 0           True            Аксессуары        RUR  115951
# 1           True               Рубашки        RUR  105651
# 2           True               Рубашки        RUR  105650
# 3           True               Рубашки        RUR  105652
# 4          False             Косметика        RUR  105940
# ...          ...                   ...        ...     ...
# 11053      False         Брюки и шорты        RUR  120819
# 11054       True  Футболки и толстовки        RUR  120893
# 11055       True  Футболки и толстовки        RUR  120890
# 11056       True  Футболки и толстовки        RUR  120891
# 11057       True  Футболки и толстовки        RUR  120892
#
#                                            model  modified_time  \
# 0                   Машинка для удаления катышек     1584439678
# 1                                Рубашка кожаная     1584460753
# 2                                Рубашка кожаная     1584460753
# ...

# %%
storeez[storeez['categoryId'] == 'Рубашки']
# Out:
#        available categoryId currencyId      id  \
# 1           True    Рубашки        RUR  105651
# 2           True    Рубашки        RUR  105650
# 3           True    Рубашки        RUR  105652
# 44          True    Рубашки        RUR  111003
# 158        False    Рубашки        RUR  112459
# ...          ...        ...        ...     ...
# 10805      False    Рубашки        RUR  120809
# 10829      False    Рубашки        RUR  120817
# 10845       True    Рубашки        RUR  114760
# 10950      False    Рубашки        RUR  113310
# 10951      False    Рубашки        RUR  114574
#
#                                 model  modified_time  \
# 1                     Рубашка кожаная     1584460753
# 2                     Рубашка кожаная     1584460753
# 3                     Рубашка кожаная     1584460753
# 44                Рубашка с карманами     1584460753
# 158      Рубашка с лентами на рукавах     1584460753
# ...                               ...            ...
# ...

# %%
storeez.count()
# Out:
# available        11058
# categoryId       11058
# currencyId       11058
# id               11058
# model            11058
# modified_time    11058
# name             11058
# oldprice          5974
# param            11058
# picture          11058
# price            11058
# type             11058
# url              11058
# vendor               0
# dtype: int64

# %%
storeez['categoryId'].unique()
# Out:
# array(['Аксессуары', 'Рубашки', 'Косметика', 'Трикотаж', 'Верхняя одежда',
#        'Платья', 'Деним', 'Брюки и шорты', 'Футболки и толстовки',
#        'Комплекты', 'Купальники', 'Топы и блузы', 'Обувь', 'Юбки',
#        'Мужская коллекция', 'Жакеты', 'Капсула октября'], dtype=object)

# %%
name = "hello"
# !mkdir {name}

# %%
for row in storeez['categoryId'].unique():
    name = '/data/storeez.com/' + row
    print(name)
    #!mkdir {name}
# Out:
# /data/storeez.com/Аксессуары
# /data/storeez.com/Рубашки
# /data/storeez.com/Косметика
# /data/storeez.com/Трикотаж
# /data/storeez.com/Верхняя одежда
# /data/storeez.com/Платья
# /data/storeez.com/Деним
# /data/storeez.com/Брюки и шорты
# /data/storeez.com/Футболки и толстовки
# /data/storeez.com/Комплекты
# /data/storeez.com/Купальники
# /data/storeez.com/Топы и блузы
# /data/storeez.com/Обувь
# /data/storeez.com/Юбки
# /data/storeez.com/Мужская коллекция
# /data/storeez.com/Жакеты
# /data/storeez.com/Капсула октября

# %%
#name = 'e://avilon.ru/images/' + storeez['categoryId'].unique()[0]
# !mkdir ./storeez['categoryId'].unique()[0]
# Out:
# ЋиЁЎЄ  ў бЁ­в ЄбЁбҐ Є®¬ ­¤л.

# %%
storeez['picture'].head(50)
# Out:
# 0     https://12storeez.com/uploads/images/CATALOG/j...
# 1     https://12storeez.com/uploads/images/CATALOG/o...
# 2     https://12storeez.com/uploads/images/CATALOG/o...
# 3     https://12storeez.com/uploads/images/CATALOG/o...
# 4     https://12storeez.com/uploads/images/CATALOG/b...
# 5     https://12storeez.com/uploads/images/CATALOG/b...
# 6     https://12storeez.com/uploads/images/CATALOG/j...
# 7     https://12storeez.com/uploads/images/CATALOG/j...
# 8     https://12storeez.com/uploads/images/CATALOG/s...
# 9     https://12storeez.com/uploads/images/CATALOG/s...
# 10    https://12storeez.com/uploads/images/CATALOG/o...
# 11    https://12storeez.com/uploads/images/CATALOG/o...
# 12    https://12storeez.com/uploads/images/CATALOG/o...
# 13    https://12storeez.com/uploads/images/CATALOG/o...
# 14    https://12storeez.com/uploads/images/CATALOG/j...
# 15    https://12storeez.com/uploads/images/CATALOG/j...
# 16    https://12storeez.com/uploads/images/CATALOG/j...
# ...

# %%
for index ,row in storeez[storeez['categoryId'] == 'Рубашки'].iterrows():
    name = './data/Рубашки'
    url = row['url']
    r = requests.get(url)     
    with open(name, 'wb') as f:
        f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-106-84f04bd03786> in <module>
#       3     url = row['url']
#       4     r = requests.get(url)
# ----> 5     with open(name, 'wb') as f:
#       6         f.write(r.content)
#
# PermissionError: [Errno 13] Permission denied: './data/Рубашки'

# %%
angle = 40

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)
      print('Img c id '+str(row['ID'])+' '+str(url)+' saved to: '+str(angle))
# Out:
# Img c id 3083666 https://avilon.ru/upload/iblock/ac2/ac2b1a43e80c5a92ae046661c46130c8.jpg saved to: 40
# Img c id 3085103 https://avilon.ru/upload/iblock/1e1/1e1d9ca7ab197069eee533a5869eac5b.jpg saved to: 40
# Img c id 3085170 https://avilon.ru/upload/iblock/59c/59c407a8707b078d04f163a283005a29.jpg saved to: 40
# Img c id 3085774 https://avilon.ru/upload/iblock/f85/f854c354e9f792629903e0733cdf1a20.jpg saved to: 40
# Img c id 3085802 https://avilon.ru/upload/iblock/d99/d99189b867892b788614f705cfee3b5f.jpg saved to: 40
# Img c id 3085827 https://avilon.ru/upload/iblock/895/895288fe678d7050ae2e8622a547aa20.jpg saved to: 40
# Img c id 3085855 https://avilon.ru/upload/iblock/161/161fc5f99109c4397e088528e4b4992a.jpg saved to: 40
# Img c id 3085879 https://avilon.ru/upload/iblock/354/354b8359af96a2fb379981b54939cc21.jpg saved to: 40
# Img c id 3085902 https://avilon.ru/upload/iblock/402/402dfdf4861b67be9911d3c118ba7bfd.jpg saved to: 40
# ...

# %%
image_set_18_03[image_set_18_03['ID'] >= 3156386]
# Out:
#             ID MARK  ... DEGREE                                            Столбец
# 29989  3156386  BMW  ...   40.0  https://avilon.ru/upload/iblock/984/98403cdb9a...
# 29990  3156387  BMW  ...  230.0  https://avilon.ru/upload/iblock/711/711ef37ebf...
# 29991  3156388  BMW  ...   90.0  https://avilon.ru/upload/iblock/6ff/6ffa2e53ca...
# 29992  3156389  BMW  ...  270.0  https://avilon.ru/upload/iblock/cfa/cfa02eb240...
# 29993  3156390  BMW  ...    0.0  https://avilon.ru/upload/iblock/e82/e82bc63e2b...
# 29994  3156391  BMW  ...  180.0  https://avilon.ru/upload/iblock/8c6/8c6fcf0d0a...
#
# [6 rows x 7 columns]

# %%
image_set_18_03
# Out:
#             ID  ...                                            Столбец
# 0      3083665  ...  https://avilon.ru/upload/iblock/987/9872050c66...
# 1      3083666  ...  https://avilon.ru/upload/iblock/ac2/ac2b1a43e8...
# 2      3085103  ...  https://avilon.ru/upload/iblock/1e1/1e1d9ca7ab...
# 3      3085104  ...  https://avilon.ru/upload/iblock/97c/97c91b14ab...
# 4      3085105  ...  https://avilon.ru/upload/iblock/ed6/ed607d6a29...
# ...        ...  ...                                                ...
# 29990  3156387  ...  https://avilon.ru/upload/iblock/711/711ef37ebf...
# 29991  3156388  ...  https://avilon.ru/upload/iblock/6ff/6ffa2e53ca...
# 29992  3156389  ...  https://avilon.ru/upload/iblock/cfa/cfa02eb240...
# 29993  3156390  ...  https://avilon.ru/upload/iblock/e82/e82bc63e2b...
# 29994  3156391  ...  https://avilon.ru/upload/iblock/8c6/8c6fcf0d0a...
#
# [10352 rows x 7 columns]

# %%
angle = [90, 140, 180, 230, 270, 320]

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] in angle:
    name = './drive/My Drive/avilon.ru/images/' + str(int(row['DEGREE'])) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)
      print('Img c id '+str(row['ID'])+' '+str(url)+' saved to: '+str(row['DEGREE']))
# Out:
# Img c id 3083665 https://avilon.ru/upload/iblock/987/9872050c663ef249267feef5df966735.jpg saved to: 140.0
# Img c id 3085104 https://avilon.ru/upload/iblock/97c/97c91b14ab2420ddcb6472f0143f872a.jpg saved to: 230.0
# Img c id 3085105 https://avilon.ru/upload/iblock/ed6/ed607d6a29514f4bceab9ed1f4b7d80b.jpg saved to: 90.0
# Img c id 3085106 https://avilon.ru/upload/iblock/c9c/c9cda72b7a1654df2222c9edefdcccd7.jpg saved to: 270.0
# Img c id 3085108 https://avilon.ru/upload/iblock/9d8/9d808de73155f4647a5a94c93dd92c94.jpg saved to: 180.0
# Img c id 3085171 https://avilon.ru/upload/iblock/6a8/6a8b3af63a8e5e284678b12292989f17.jpg saved to: 270.0
# Img c id 3085775 https://avilon.ru/upload/iblock/095/095afb5c64c4fa949a8f99d50711d013.jpg saved to: 230.0
# Img c id 3085776 https://avilon.ru/upload/iblock/5a3/5a3358e99161c6bb7e41e8033ebf232e.jpg saved to: 90.0
# Img c id 3085777 https://avilon.ru/upload/iblock/fde/fde4c06f49696f3b5971005a0e8babfe.jpg saved to: 270.0
# ...

# %%
angle = 40

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)
      print('Img c id '+str(row['ID'])+' '+str(url)+' saved to: '+str(angle))
# Out:
# Img c id 3083666 https://avilon.ru/upload/iblock/ac2/ac2b1a43e80c5a92ae046661c46130c8.jpg saved to: 40
# Img c id 3085103 https://avilon.ru/upload/iblock/1e1/1e1d9ca7ab197069eee533a5869eac5b.jpg saved to: 40
# Img c id 3085170 https://avilon.ru/upload/iblock/59c/59c407a8707b078d04f163a283005a29.jpg saved to: 40
# Img c id 3085774 https://avilon.ru/upload/iblock/f85/f854c354e9f792629903e0733cdf1a20.jpg saved to: 40
# Img c id 3085802 https://avilon.ru/upload/iblock/d99/d99189b867892b788614f705cfee3b5f.jpg saved to: 40
# Img c id 3085827 https://avilon.ru/upload/iblock/895/895288fe678d7050ae2e8622a547aa20.jpg saved to: 40
# Img c id 3085855 https://avilon.ru/upload/iblock/161/161fc5f99109c4397e088528e4b4992a.jpg saved to: 40
# Img c id 3085879 https://avilon.ru/upload/iblock/354/354b8359af96a2fb379981b54939cc21.jpg saved to: 40
# Img c id 3085902 https://avilon.ru/upload/iblock/402/402dfdf4861b67be9911d3c118ba7bfd.jpg saved to: 40
# ...

# %%
angle = 40

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)
      print('Img c id '+str(row['ID'])+' '+str(url)+' saved to: '+str(angle))
# Out:
# Img c id 3083666 https://avilon.ru/upload/iblock/ac2/ac2b1a43e80c5a92ae046661c46130c8.jpg saved to: 40
# Img c id 3085103 https://avilon.ru/upload/iblock/1e1/1e1d9ca7ab197069eee533a5869eac5b.jpg saved to: 40
# Img c id 3085170 https://avilon.ru/upload/iblock/59c/59c407a8707b078d04f163a283005a29.jpg saved to: 40
# Img c id 3085774 https://avilon.ru/upload/iblock/f85/f854c354e9f792629903e0733cdf1a20.jpg saved to: 40
# Img c id 3085802 https://avilon.ru/upload/iblock/d99/d99189b867892b788614f705cfee3b5f.jpg saved to: 40
# Img c id 3085827 https://avilon.ru/upload/iblock/895/895288fe678d7050ae2e8622a547aa20.jpg saved to: 40
# Img c id 3085855 https://avilon.ru/upload/iblock/161/161fc5f99109c4397e088528e4b4992a.jpg saved to: 40
# Img c id 3085879 https://avilon.ru/upload/iblock/354/354b8359af96a2fb379981b54939cc21.jpg saved to: 40
# Img c id 3085902 https://avilon.ru/upload/iblock/402/402dfdf4861b67be9911d3c118ba7bfd.jpg saved to: 40
# ...

# %%
angle = 90

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle = 140

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle = 180

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle = 230

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle = 270

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle = 320

for index ,row in image_set_18_03.iterrows():
  if row['DEGREE'] == angle:
    name = './drive/My Drive/avilon.ru/data/source/' + str(angle) + '/' + str(row['ID'])+'.jpg'
    url = row['Столбец']
    r = requests.get(url)  
    with open(name, 'wb') as f:
      f.write(r.content)

# %%
angle_0 = image_set_18_03[image_set_18_03['DEGREE'] == 0]
angle_40 = image_set_18_03[image_set_18_03['DEGREE'] == 40]
angle_90 = image_set_18_03[image_set_18_03['DEGREE'] == 90]
angle_140 = image_set_18_03[image_set_18_03['DEGREE'] == 140]
angle_180 = image_set_18_03[image_set_18_03['DEGREE'] == 180]
angle_230 = image_set_18_03[image_set_18_03['DEGREE'] == 230]
angle_270 = image_set_18_03[image_set_18_03['DEGREE'] == 270]
angle_320 = image_set_18_03[image_set_18_03['DEGREE'] == 320]

# %%
angle_0
# Out:
#             ID  ...                                            Столбец
# 6      3085107  ...  https://avilon.ru/upload/iblock/fea/fea3ff4b28...
# 31     3085778  ...  https://avilon.ru/upload/iblock/65b/65bad4895f...
# 55     3085806  ...  https://avilon.ru/upload/iblock/6f7/6f7ebfd6c7...
# 78     3085831  ...  https://avilon.ru/upload/iblock/66a/66a4aa7eab...
# 98     3085859  ...  https://avilon.ru/upload/iblock/76c/76c51b35f8...
# ...        ...  ...                                                ...
# 29907  3156200  ...  https://avilon.ru/upload/iblock/d8e/d8e9650249...
# 29924  3156221  ...  https://avilon.ru/upload/iblock/859/859c04eeda...
# 29946  3156246  ...  https://avilon.ru/upload/iblock/cab/cab7afcbdd...
# 29973  3156285  ...  https://avilon.ru/upload/iblock/f12/f12aa5f1b6...
# 29993  3156390  ...  https://avilon.ru/upload/iblock/e82/e82bc63e2b...
#
# [1467 rows x 7 columns]
